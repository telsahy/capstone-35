# %%
import nltk

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Instantiate cleaned pickles

# %%
df_batch_1 = pd.read_pickle('../gulf_twitter_pickled/stream_مغسلة.p')

# %% [markdown]
# ### Identify most frequent `geo` and `name`

# %%
df_batch_1.cleaned_geo.value_counts().head()
# Out:
# None                                         61
# جدة, المملكة العربية السعودية                 9
# المملكة العربية السعودية                      7
# المدينة المنورة, المملكة العربية السعودية     4
# Riyadh | للإعلان التواصل خاص                  4
# Name: cleaned_geo, dtype: int64

# %%
df_batch_1.cleaned_name.value_counts().head()
# Out:
# shbr11          4
# Ask_Riyadh1     4
# Dahan_Co        4
# Ask_Almadina    4
# mnoor496        2
# Name: cleaned_name, dtype: int64

# %%
df_batch_1.cleaned_name.value_counts().hist()

# %%
df_batch_1.cleaned_geo.value_counts().hist()

# %%
df_batch_1.cleaned_geo.unique()
# Out:
# array(['None', 'بِدبِد - SQU - معبيلة سيتي', 'وطني الغالي', 'MAKKAH',
#        'Jeddah', '', 'khobar ksa - akkar lebanon', 'مومباي/ الهند',
#        'في قلبها ... في قلبه', 'جدة, المملكة العربية السعودية', 'ليبيا',
#        'المدينة المنورة, المملكة العربية السعودية', 'جــــــــــــدة',
#        'المملكة العربية السعودية', 'makkah - saudi arabia',
#        'Riyadh | للإعلان التواصل خاص', 'مومباي . الهند',
#        'سكاكا, المملكة العربية السعودية', 'Dammam, Eastern',
#        'BAHA, Kingdom of Saudia Arabia', 'abn-Alkuwait', 'Kuwait - الكويت',
#        'Saudi , Riyadh', 'Dammam', 'Gaza',
#        'الرياض, المملكة العربية السعودية', 'القصيم',
#        'الرياض، جدة | دبي، أبوظبي',
#        'مكة المكرمة, المملكة العربية السعودية', 'القصيم-الشماسية',
#        'الدمام, المملكة العربية السعودية', 'In the middle of nowhere',
#        'المدينة المنورة', 'Makkah Al Mukarrama, Kingdom of Saudi Arabia',
#        'الخبر', 'لقائنا في الجنة بإذن الله', 'امووت بالزعيم - جدة',
# ...

# %%
geo_list = list(df_batch_1['cleaned_geo'].value_counts().head())

# %%
geo_list
# Out:
# [61, 9, 7, 4, 4]

# %%
df_batch_1.columns.str.strip()
# Out:
# Index(['cleaned_text', 'cleaned_name', 'cleaned_geo'], dtype='object')

# %%
df_batch_1.columns = df_batch_1.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df_batch_1.columns
# Out:
# Index(['cleaned_text', 'cleaned_name', 'cleaned_geo'], dtype='object')

# %%
df_batch_1.index
# Out:
# Int64Index([  0,   1,   2,   3,   6,   7,   8,   9,  10,  12,
#             ...
#             239, 240, 241, 242, 243, 244, 245, 246, 247, 248],
#            dtype='int64', length=155)

# %%
df_batch_1['cleaned_geo'].str.split('_', expand=True)
# Out:
#                                              0     1
# 0                                         None  None
# 1                   بِدبِد - SQU - معبيلة سيتي  None
# 2                                  وطني الغالي  None
# 3                                       MAKKAH  None
# 6                                         None  None
# 7                                       Jeddah  None
# 8                                         None  None
# 9                                         None  None
# 10                                        None  None
# 12                                        None  None
# 13                                        None  None
# 14                                        None  None
# 16                                              None
# 17                                        None  None
# 24                                        None  None
# 25                  khobar ksa - akkar lebanon  None
# 26                                        None  None
# ...

# %%
#pseudo code
locations = {'saudi arabia': ['Kingdom of Saudi Arabia', 'MAKKAH'],
             ''

for word in df_batch_1['cleaned_geo'].str.split('_'):
    if word in saudi_locations:
        df_batch_1['cleaned_geo'].replace(word, 'Saudi Arabia', inplace=True)

# %%
df_batch_1['cleaned_geo'].str.split('_', expand=True).head()
# Out:
#                             0     1
# 0                        None  None
# 1  بِدبِد - SQU - معبيلة سيتي  None
# 2                 وطني الغالي  None
# 3                      MAKKAH  None
# 6                        None  None

# %%
df_batch_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 248
# Data columns (total 3 columns):
# cleaned_text    155 non-null object
# cleaned_name    155 non-null object
# cleaned_geo     155 non-null object
# dtypes: object(3)
# memory usage: 4.8+ KB

# %%
locations_list = []
for word in df_batch_1['cleaned_geo'].str.split('_'):
    locations_list.append(word)

# %%
locations_list
# Out:
# [['None'],
#  ['بِدبِد - SQU - معبيلة سيتي'],
#  ['وطني الغالي'],
#  ['MAKKAH'],
#  ['None'],
#  ['Jeddah'],
#  ['None'],
#  ['None'],
#  ['None'],
#  ['None'],
#  ['None'],
#  ['None'],
#  [''],
#  ['None'],
#  ['None'],
#  ['khobar ksa - akkar lebanon'],
#  ['None'],
#  ['مومباي/ الهند'],
#  ['None'],
#  ['في قلبها ... في قلبه'],
#  ['جدة, المملكة العربية السعودية'],
#  [''],
#  ['ليبيا'],
#  ['None'],
#  ['جدة, المملكة العربية السعودية'],
#  ['المدينة المنورة, المملكة العربية السعودية'],
#  ['None'],
#  ['None'],
#  ['جــــــــــــدة'],
#  ['المملكة العربية السعودية'],
#  ['makkah - saudi arabia'],
#  ['None'],
#  ['Riyadh | للإعلان التواصل خاص'],
#  ['Riyadh | للإعلان التواصل خاص'],
#  ['None'],
#  ['Riyadh | للإعلان التواصل خاص'],
#  ['Riyadh | للإعلان التواصل خاص'],
#  ['None'],
#  ['None'],
#  ['None'],
#  ['None'],
#  ['None'],
#  ['None'],
#  ['مومباي . الهند'],
#  ['None'],
#  ['سكاكا, المملكة العربية السعودية'],
#  ['None'],
#  ['Dammam, Eastern'],
#  ['None'],
# ...

# %%
word_list = []
for word in df_batch_1['cleaned_text'].str.split('_'):
    word_list.append(word)

# %%
word_list[:2]
# Out:
# [['شوف لك مغسلة سيارات قبل يحرقوها عليك'],
#  ['حتى هندي مال مغسلة قال لي تدرس هندسة وحده عرف']]

# %%
V = set(word_list)
long_words = [w for w in V if len(w) > 10]
sorted(long_words)
# Out:
# ['أفكار_خيرية',
#  'الاوتوماتيكيه',
#  'الايطالي،من',
#  'النرجس:للايجار',
#  'ملاااااااابس،،،متنقلة',
#  'والاكسسوارات…']

# %%
word_list = [word for line in df_batch_1['cleaned_text'] for word in line.split()]

# %%
word_list.count('مغسلة')
# Out:
# 135

# %%
len(word_list)
# Out:
# 2332

# %%
vocab = set(word_list)
vocab_size = len(vocab)
vocab_size
# Out:
# 1067

# %%
from nltk.text import Text  
moby = Text(word_list)

# %%
moby.concordance("مغسلة")
# Out:
# Displaying 25 of 135 matches:
#                                      مغسلة سيارات قبل يحرقوها عليك حتى هندي مال
#                                      مغسلة قال لي تدرس هندسة وحده عرف يتعطل عند
#  تدرس هندسة وحده عرف يتعطل عندك خلاط مغسلة تروح مكتب مؤسسة صيانة يستقبلك صاحب ا
# تب سعودي تتفق معه وتأخذ… مخطط من بعد مغسلة الضاحي مغسلة طيبه الاوتوماتيكيه اسعا
#  معه وتأخذ… مخطط من بعد مغسلة الضاحي مغسلة طيبه الاوتوماتيكيه اسعارهم حلوه مغسل
# غسلة طيبه الاوتوماتيكيه اسعارهم حلوه مغسلة مركبة بمسمارين و شوية سيلكون مصيرها
#  استثماري في اليمن..؟ قال :احسن… فيه مغسلة في مخطط الملك فهد، جنب محطة الوصابي
# ونها صدقة ، بس للاسف ان… : شباب فتحت مغسلة سيارات لغسل السيارة من الداخل والخار
#  لما كبرو شوفو الي واقفين بالدور عند مغسلة السيارات بمحطات الوق… مركز مغسلة فوم
# عند مغسلة السيارات بمحطات الوق… مركز مغسلة فومي للسيارات *عندهم خصومات طيبة تبد
#  Jeddah … : ياقو قلبك ياشيخ كيف تدخل مغسلة اموات في مكان مهجور 🤐🤐 يَــب قصدك ال
# ...

# %%
from nltk import FreqDist

# %%
fdist1 = FreqDist(moby)

# %%
fdist1
# Out:
# FreqDist({'شوف': 2,
#           'لك': 8,
#           'مغسلة': 135,
#           'سيارات': 21,
#           'قبل': 2,
#           'يحرقوها': 1,
#           'عليك': 3,
#           'حتى': 4,
#           'هندي': 1,
#           'مال': 1,
#           'قال': 3,
#           'لي': 3,
#           'تدرس': 1,
#           'هندسة': 1,
#           'وحده': 1,
#           'عرف': 1,
#           'يتعطل': 1,
#           'عندك': 1,
#           'خلاط': 3,
#           'تروح': 1,
#           'مكتب': 2,
#           'مؤسسة': 2,
#           'صيانة': 1,
#           'يستقبلك': 1,
#           'صاحب': 1,
#           'المكتب': 1,
#           'سعودي': 1,
#           'تتفق': 1,
#           'معه': 1,
#           'وتأخذ…': 1,
#           'مخطط': 2,
#           'من': 59,
#           'بعد': 2,
#           'الضاحي': 1,
#           'طيبه': 1,
#           'الاوتوماتيكيه': 1,
#           'اسعارهم': 1,
#           'حلوه': 1,
#           'مركبة': 1,
#           'بمسمارين': 1,
#           'و': 19,
#           'شوية': 1,
# ...

# %%
vocabulary1 = list(fdist1.keys())
vocabulary1[:10]
# Out:
# ['شوف',
#  'لك',
#  'مغسلة',
#  'سيارات',
#  'قبل',
#  'يحرقوها',
#  'عليك',
#  'حتى',
#  'هندي',
#  'مال']

# %%
fdist1.plot(50, cumulative=True)

# %%
moby.dispersion_plot([u"مغسلة", "ياخذون", "فقط", "داخل", "عايز"])

# %%
moby.similar("مغسلة")
# Out:
# نظافة معماري الجبس استراحة منزلي القطعه

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

def percentage(count, total):
    return 100 * count / total

# %%
lexical_diversity(moby)
# Out:
# 0.45754716981132076

# %%
percentage(moby.count('مغسلة'), len(moby))
# Out:
# 5.789022298456261

# %%
sorted([w for w in set(word_list) if len(w) > 2 and fdist1[w] > 10])
# Out:
# ['السلام',
#  'اللي',
#  'بأكثر',
#  'ريال',
#  'سيارات',
#  'عامل',
#  'على',
#  'عليكم',
#  'لون',
#  'مغسلة',
#  'ملابس',
#  'موديل']
